# %%
import numpy as np
import os
import pandas as pd
from keras.models import Model, Sequential
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'c:\\Users\\piyus\\Downloads\\deep-learning\\DL04_CNN\\05_Keras Functional Model'

# %%
os.listdir(r'/Projects/P4 - Multi Output NN/data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.listdir(r'/Projects/P4 - Multi Output NN/data')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/Projects/P4 - Multi Output NN/data'

# %%
from keras.layers import *
x = Input(shape=(3,))

# %%
from keras.applications import VGG16
vgg = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
model = Sequential([
    vgg,
    Flatten(),
])
model.summary()
