# %%
import os
import json

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

import tensorflow
from tensorflow import keras
from keras import Sequential
from keras_preprocessing import image
from keras.layers import Dense, Flatten, Dropout
from keras_preprocessing.image import ImageDataGenerator

# %%
np.random.seed(0)
tensorflow.random.set_seed(0)

# %%
os.listdir('PlantVillage')
# Out:
# ['color', 'grayscale', 'segmented']

# %%
len(os.listdir(r'PlantVillage/color'))  # 38 classes
os.listdir(r'PlantVillage/color')[:5]
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy']

# %%
base_dir = 'PlantVillage/color/'

# %%
image_path = os.path.join(base_dir, r'Apple___healthy/0a02e8cb-b715-497f-a16a-c28b3409f927___RS_HL 7432.JPG')
img = mpimg.imread(image_path)
plt.imshow(img)
img.shape
# Out:
# (256, 256, 3)
